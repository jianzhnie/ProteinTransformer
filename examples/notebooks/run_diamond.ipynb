# %%
import os
import sys
import logging
import subprocess
import pandas as pd

# %% [markdown]
# # Prepare FASTA files for diamond

# %%
base_path = u"/Users/robin/xbiome/datasets/protein"
base_path = u"/home/niejianzheng/xbiome/datasets/protein"

# Pandas dataframe with protein sequences
train_data_file = os.path.join(base_path, u"train_data.pkl")
# Fasta file
train_FASTA_file = os.path.join(base_path, u"train_data.fa")
# DIAMOND database file from train dataset
train_diamond_db = os.path.join(base_path, u"train_data.dmnd")

# Pandas dataframe with protein sequences
test_data_file = os.path.join(base_path, u"test_data.pkl")
# Fasta file
test_FASTA_file = os.path.join(base_path, u"test_data.fa")
# Diamond Mapping file for test dataset
test_diamond_file = os.path.join(base_path, u"test_diamond.res")

# %%
def save_seq_to_FASTA(data_file, FASTA_file):
    # load DataFrame file
    df = pd.read_pickle(data_file)

    # save proteins and sequences to FASTA format file
    with open(FASTA_file, 'w') as f:
        for row in df.itertuples():
            f.write('>' + row.proteins + '\n')
            f.write(row.sequences + '\n')

    if os.path.exists(FASTA_file):
        print("%d sequences are saved to FASTA file %s."%(len(df), FASTA_file))
        return True
    else:
        return False

# %%
save_seq_to_FASTA(train_data_file, train_FASTA_file)
save_seq_to_FASTA(test_data_file, test_FASTA_file)
# Out:
# 73592 sequences are saved to FASTA file /home/niejianzheng/xbiome/datasets/protein/train_data.fa.
# 3874 sequences are saved to FASTA file /home/niejianzheng/xbiome/datasets/protein/test_data.fa.
# True

# %% [markdown]
# # Create diamond database from train dataset

# %%
cmd = ["diamond", "makedb",  "--db", train_diamond_db, "--in", train_FASTA_file]

proc = subprocess.run(cmd)

if proc.returncode != 0:
    logging.error('Error running diamond!')
    sys.exit(1)
# Out:
# diamond v0.9.14.115 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU AGPL <https://www.gnu.org/licenses/agpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 64
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database file: /home/niejianzheng/xbiome/datasets/protein/train_data.fa
# Opening the database file...  [0.001405s]
# Loading sequences...  [0.144372s]
# Masking sequences...  [0.277087s]
# Writing sequences...  [0.040969s]
# Loading sequences...  [2e-05s]
# Writing trailer...  [0.000223s]
# Closing the input file...  [2e-05s]
# Closing the database file...  [0.000231s]
# Processed 73592 sequences, 38780826 letters.
# Total time = 0.464423s

# %% [markdown]
# # Generate diamond scores for test dataset

# %%
cmd = ["diamond", "blastp",  "-d", train_diamond_db, "--more-sensitive", "-t", "/tmp",
       "-q", test_FASTA_file, "--outfmt", "6", "qseqid", "sseqid", "bitscore", "-o",
       test_diamond_file]

proc = subprocess.run(cmd)

if proc.returncode != 0:
    logging.error('Error running diamond!')
    sys.exit(1)
# Out:
# diamond v0.9.14.115 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU AGPL <https://www.gnu.org/licenses/agpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 64
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# #Target sequences to report alignments for: 25
# Temporary directory: /tmp
# Opening the database...  [6.7e-05s]
# Opening the input file...  [0.000106s]
# Opening the output file...  [0.000391s]
# Loading query sequences...  [0.008764s]
# Masking queries...  [0.027399s]
# Building query seed set...  [0.000636s]
# Algorithm: Double-indexed
# Building query histograms...  [0.020048s]
# Allocating buffers...  [0.00254s]
# Loading reference sequences...  [0.071225s]
# Building reference histograms...  [0.265301s]
# Allocating buffers...  [0.005835s]
# Initializing temporary storage...  [0.026814s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 0.
# Building reference index...  [0.059595s]
# Building query index...  [0.015684s]
# Building seed filter...  [0.015081s]
# Searching alignments...  [0.060335s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 1.
# Building reference index...  [0.064201s]
# Building query index...  [0.022165s]
# Building seed filter...  [0.016483s]
# Searching alignments...  [0.039913s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 2.
# Building reference index...  [0.060006s]
# Building query index...  [0.019258s]
# Building seed filter...  [0.01506s]
# Searching alignments...  [0.034799s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 3.
# Building reference index...  [0.058779s]
# Building query index...  [0.020231s]
# Building seed filter...  [0.015018s]
# Searching alignments...  [0.036649s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 0.
# Building reference index...  [0.058699s]
# Building query index...  [0.019689s]
# Building seed filter...  [0.0141s]
# Searching alignments...  [0.02851s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 1.
# Building reference index...  [0.05966s]
# Building query index...  [0.021693s]
# Building seed filter...  [0.015837s]
# Searching alignments...  [0.030522s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 2.
# Building reference index...  [0.05832s]
# Building query index...  [0.018514s]
# Building seed filter...  [0.014535s]
# Searching alignments...  [0.028244s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 3.
# Building reference index...  [0.052598s]
# Building query index...  [0.022597s]
# Building seed filter...  [0.015199s]
# Searching alignments...  [0.031658s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 0.
# Building reference index...  [0.060882s]
# Building query index...  [0.01927s]
# Building seed filter...  [0.014657s]
# Searching alignments...  [0.04276s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 1.
# Building reference index...  [0.063537s]
# Building query index...  [0.01866s]
# Building seed filter...  [0.014664s]
# Searching alignments...  [0.041909s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 2.
# Building reference index...  [0.061801s]
# Building query index...  [0.024738s]
# Building seed filter...  [0.017567s]
# Searching alignments...  [0.032914s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 3.
# Building reference index...  [0.055706s]
# Building query index...  [0.022252s]
# Building seed filter...  [0.015824s]
# Searching alignments...  [0.030782s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 0.
# Building reference index...  [0.056834s]
# Building query index...  [0.019337s]
# Building seed filter...  [0.015301s]
# Searching alignments...  [0.031251s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 1.
# Building reference index...  [0.057583s]
# Building query index...  [0.019365s]
# Building seed filter...  [0.014876s]
# Searching alignments...  [0.042477s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 2.
# Building reference index...  [0.070908s]
# Building query index...  [0.018438s]
# Building seed filter...  [0.01465s]
# Searching alignments...  [0.028325s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 3.
# Building reference index...  [0.051716s]
# Building query index...  [0.019766s]
# Building seed filter...  [0.014863s]
# Searching alignments...  [0.033807s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 0.
# Building reference index...  [0.054947s]
# Building query index...  [0.018035s]
# Building seed filter...  [0.014887s]
# Searching alignments...  [0.030035s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 1.
# Building reference index...  [0.056872s]
# Building query index...  [0.023021s]
# Building seed filter...  [0.014908s]
# Searching alignments...  [0.030468s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 2.
# Building reference index...  [0.059877s]
# Building query index...  [0.019609s]
# Building seed filter...  [0.016186s]
# Searching alignments...  [0.030763s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 3.
# Building reference index...  [0.055233s]
# Building query index...  [0.020059s]
# Building seed filter...  [0.017035s]
# Searching alignments...  [0.030907s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 0.
# Building reference index...  [0.058307s]
# Building query index...  [0.019648s]
# Building seed filter...  [0.015609s]
# Searching alignments...  [0.031717s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 1.
# Building reference index...  [0.058475s]
# Building query index...  [0.021346s]
# Building seed filter...  [0.015542s]
# Searching alignments...  [0.029905s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 2.
# Building reference index...  [0.064164s]
# Building query index...  [0.01895s]
# Building seed filter...  [0.01462s]
# Searching alignments...  [0.032146s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 3.
# Building reference index...  [0.056427s]
# Building query index...  [0.018747s]
# Building seed filter...  [0.014806s]
# Searching alignments...  [0.039186s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 0.
# Building reference index...  [0.057073s]
# Building query index...  [0.01982s]
# Building seed filter...  [0.014769s]
# Searching alignments...  [0.027395s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 1.
# Building reference index...  [0.059248s]
# Building query index...  [0.019076s]
# Building seed filter...  [0.014274s]
# Searching alignments...  [0.026447s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 2.
# Building reference index...  [0.060611s]
# Building query index...  [0.018427s]
# Building seed filter...  [0.014863s]
# Searching alignments...  [0.028018s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 3.
# Building reference index...  [0.052959s]
# Building query index...  [0.019542s]
# Building seed filter...  [0.014828s]
# Searching alignments...  [0.035693s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 0.
# Building reference index...  [0.059021s]
# Building query index...  [0.020147s]
# Building seed filter...  [0.016892s]
# Searching alignments...  [0.030037s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 1.
# Building reference index...  [0.057364s]
# Building query index...  [0.018861s]
# Building seed filter...  [0.015156s]
# Searching alignments...  [0.030917s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 2.
# Building reference index...  [0.060044s]
# Building query index...  [0.01824s]
# Building seed filter...  [0.014296s]
# Searching alignments...  [0.029086s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 3.
# Building reference index...  [0.058652s]
# Building query index...  [0.019058s]
# Building seed filter...  [0.01545s]
# Searching alignments...  [0.032525s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 0.
# Building reference index...  [0.056636s]
# Building query index...  [0.018601s]
# Building seed filter...  [0.014555s]
# Searching alignments...  [0.028334s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 1.
# Building reference index...  [0.058684s]
# Building query index...  [0.018667s]
# Building seed filter...  [0.013109s]
# Searching alignments...  [0.029804s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 2.
# Building reference index...  [0.060683s]
# Building query index...  [0.019073s]
# Building seed filter...  [0.014955s]
# Searching alignments...  [0.042633s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 3.
# Building reference index...  [0.065714s]
# Building query index...  [0.018646s]
# Building seed filter...  [0.014693s]
# Searching alignments...  [0.036626s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 0.
# Building reference index...  [0.055852s]
# Building query index...  [0.0192s]
# Building seed filter...  [0.014791s]
# Searching alignments...  [0.027586s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 1.
# Building reference index...  [0.055073s]
# Building query index...  [0.018912s]
# Building seed filter...  [0.015195s]
# Searching alignments...  [0.031249s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 2.
# Building reference index...  [0.059276s]
# Building query index...  [0.024753s]
# Building seed filter...  [0.018935s]
# Searching alignments...  [0.028885s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 3.
# Building reference index...  [0.051961s]
# Building query index...  [0.019943s]
# Building seed filter...  [0.014828s]
# Searching alignments...  [0.027663s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 0.
# Building reference index...  [0.054419s]
# Building query index...  [0.018816s]
# Building seed filter...  [0.014668s]
# Searching alignments...  [0.034475s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 1.
# Building reference index...  [0.05824s]
# Building query index...  [0.019394s]
# Building seed filter...  [0.015036s]
# Searching alignments...  [0.030656s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 2.
# Building reference index...  [0.059807s]
# Building query index...  [0.018411s]
# Building seed filter...  [0.014382s]
# Searching alignments...  [0.030975s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 3.
# Building reference index...  [0.054969s]
# Building query index...  [0.019051s]
# Building seed filter...  [0.01512s]
# Searching alignments...  [0.036115s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 0.
# Building reference index...  [0.053856s]
# Building query index...  [0.018607s]
# Building seed filter...  [0.014771s]
# Searching alignments...  [0.027426s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 1.
# Building reference index...  [0.057646s]
# Building query index...  [0.019016s]
# Building seed filter...  [0.014234s]
# Searching alignments...  [0.027623s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 2.
# Building reference index...  [0.057865s]
# Building query index...  [0.018906s]
# Building seed filter...  [0.014963s]
# Searching alignments...  [0.027557s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 3.
# Building reference index...  [0.05371s]
# Building query index...  [0.019851s]
# Building seed filter...  [0.014408s]
# Searching alignments...  [0.028533s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 0.
# Building reference index...  [0.055761s]
# Building query index...  [0.020023s]
# Building seed filter...  [0.015106s]
# Searching alignments...  [0.030284s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 1.
# Building reference index...  [0.058641s]
# Building query index...  [0.019317s]
# Building seed filter...  [0.014549s]
# Searching alignments...  [0.028034s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 2.
# Building reference index...  [0.062294s]
# Building query index...  [0.018668s]
# Building seed filter...  [0.014526s]
# Searching alignments...  [0.035496s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 3.
# Building reference index...  [0.055951s]
# Building query index...  [0.018041s]
# Building seed filter...  [0.014783s]
# Searching alignments...  [0.028578s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 0.
# Building reference index...  [0.055211s]
# Building query index...  [0.023561s]
# Building seed filter...  [0.015159s]
# Searching alignments...  [0.030987s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 1.
# Building reference index...  [0.058018s]
# Building query index...  [0.018665s]
# Building seed filter...  [0.014329s]
# Searching alignments...  [0.028923s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 2.
# Building reference index...  [0.055629s]
# Building query index...  [0.019342s]
# Building seed filter...  [0.015077s]
# Searching alignments...  [0.031363s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 3.
# Building reference index...  [0.054389s]
# Building query index...  [0.019504s]
# Building seed filter...  [0.014858s]
# Searching alignments...  [0.027973s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 0.
# Building reference index...  [0.052786s]
# Building query index...  [0.018815s]
# Building seed filter...  [0.01522s]
# Searching alignments...  [0.044003s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 1.
# Building reference index...  [0.068066s]
# Building query index...  [0.019634s]
# Building seed filter...  [0.014773s]
# Searching alignments...  [0.029295s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 2.
# Building reference index...  [0.058239s]
# Building query index...  [0.018425s]
# Building seed filter...  [0.015076s]
# Searching alignments...  [0.028696s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 3.
# Building reference index...  [0.054834s]
# Building query index...  [0.019292s]
# Building seed filter...  [0.014077s]
# Searching alignments...  [0.043817s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 0.
# Building reference index...  [0.065383s]
# Building query index...  [0.019407s]
# Building seed filter...  [0.014466s]
# Searching alignments...  [0.027549s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 1.
# Building reference index...  [0.059352s]
# Building query index...  [0.019279s]
# Building seed filter...  [0.01495s]
# Searching alignments...  [0.036032s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 2.
# Building reference index...  [0.060174s]
# Building query index...  [0.018509s]
# Building seed filter...  [0.014628s]
# Searching alignments...  [0.028272s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 3.
# Building reference index...  [0.052946s]
# Building query index...  [0.019482s]
# Building seed filter...  [0.015197s]
# Searching alignments...  [0.028054s]
# Deallocating buffers...  [0.000405s]
# Computing alignments...  [0.639197s]
# Deallocating reference...  [0.000998s]
# Loading reference sequences...  [4.3e-05s]
# Deallocating buffers...  [0.000411s]
# Deallocating queries...  [0.000117s]
# Loading query sequences...  [2.8e-05s]
# Closing the input file...  [2.8e-05s]
# Closing the output file...  [0.000256s]
# Closing the database file...  [1.8e-05s]
# Total time = 9.09112s
# Reported 51679 pairwise alignments, 52204 HSPs.
# 3501 queries aligned.
