# %%
import os
import sys
import subprocess
import pandas as pd

# %% [markdown]
# # Prepare FASTA files for diamond

# %%
base_path = u"/Users/robin/xbiome/datasets/protein"

# Pandas dataframe with protein sequences
train_data_file = os.path.join(base_path, u"train_data.pkl")
# Fasta file
train_FASTA_file = os.path.join(base_path, u"train_data.fa")
# DIAMOND database file from train dataset
train_diamond_db = os.path.join(base_path, u"train_data.dmnd")

# Pandas dataframe with protein sequences
test_data_file = os.path.join(base_path, u"test_data.pkl")
# Fasta file
test_FASTA_file = os.path.join(base_path, u"test_data.fa")
# Diamond Mapping file for test dataset
test_diamond_file = os.path.join(base_path, u"test_diamond.res")

# %%
def save_seq_to_FASTA(data_file, FASTA_file):
    # load DataFrame file
    df = pd.read_pickle(data_file)

    # save proteins and sequences to FASTA format file
    with open(FASTA_file, 'w') as f:
        for row in df.itertuples():
            f.write('>' + row.proteins + '\n')
            f.write(row.sequences + '\n')

    if os.path.exists(FASTA_file):
        print("%d sequences are saved to FASTA file %s."%(len(df), FASTA_file))
        return True
    else:
        return False

# %%
save_seq_to_FASTA(train_data_file, train_FASTA_file)
save_seq_to_FASTA(test_data_file, test_FASTA_file)
# Out:
# 73592 sequences are saved to FASTA file /Users/robin/xbiome/datasets/protein/train_data.fa.
# 3874 sequences are saved to FASTA file /Users/robin/xbiome/datasets/protein/test_data.fa.
# True

# %% [markdown]
# # Create diamond database from train dataset

# %%
cmd = ["diamond", "makedb",  "--db", train_diamond_db, "--in", train_FASTA_file]

proc = subprocess.run(cmd)

if proc.returncode != 0:
    logging.error('Error running diamond!')
    sys.exit(1)
# Out:
# diamond v0.9.14.115 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU AGPL <https://www.gnu.org/licenses/agpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database file: /Users/robin/xbiome/datasets/protein/train_data.fa
# Opening the database file...  [0.000426s]
# Loading sequences...  [0.20599s]
# Masking sequences...  [2.40989s]
# Writing sequences...  [0.080624s]
# Loading sequences...  [1.5e-05s]
# Writing trailer...  [0.003948s]
# Closing the input file...  [2.6e-05s]
# Closing the database file...  [0.000357s]
# Processed 73592 sequences, 38780826 letters.
# Total time = 2.70137s

# %% [markdown]
# # Generate diamond scores for test dataset

# %%
cmd = ["diamond", "blastp",  "-d", train_diamond_db, "--more-sensitive", "-t", "/tmp",
       "-q", test_FASTA_file, "--outfmt", "6", "qseqid", "sseqid", "bitscore", "-o",
       test_diamond_file]

proc = subprocess.run(cmd)

if proc.returncode != 0:
    logging.error('Error running diamond!')
    sys.exit(1)
# Out:
# diamond v0.9.14.115 | by Benjamin Buchfink <buchfink@gmail.com>
# Licensed under the GNU AGPL <https://www.gnu.org/licenses/agpl.txt>
# Check http://github.com/bbuchfink/diamond for updates.
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# #Target sequences to report alignments for: 25
# Temporary directory: /tmp
# Opening the database...  [4.8e-05s]
# Opening the input file...  [0.000233s]
# Opening the output file...  [0.002833s]
# Loading query sequences...  [0.008808s]
# Masking queries...  [0.101426s]
# Building query seed set...  [0.000375s]
# Algorithm: Double-indexed
# Building query histograms...  [0.044475s]
# Allocating buffers...  [9.7e-05s]
# Loading reference sequences...  [0.082508s]
# Building reference histograms...  [1.38256s]
# Allocating buffers...  [0.000127s]
# Initializing temporary storage...  [0.017009s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 0.
# Building reference index...  [0.234147s]
# Building query index...  [0.011482s]
# Building seed filter...  [0.019075s]
# Searching alignments...  [0.143836s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 1.
# Building reference index...  [0.311474s]
# Building query index...  [0.012204s]
# Building seed filter...  [0.01823s]
# Searching alignments...  [0.140119s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 2.
# Building reference index...  [0.322063s]
# Building query index...  [0.015467s]
# Building seed filter...  [0.017388s]
# Searching alignments...  [0.121043s]
# Processing query chunk 0, reference chunk 0, shape 0, index chunk 3.
# Building reference index...  [0.276899s]
# Building query index...  [0.013707s]
# Building seed filter...  [0.017209s]
# Searching alignments...  [0.116876s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 0.
# Building reference index...  [0.260402s]
# Building query index...  [0.011029s]
# Building seed filter...  [0.018057s]
# Searching alignments...  [0.111245s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 1.
# Building reference index...  [0.284534s]
# Building query index...  [0.012585s]
# Building seed filter...  [0.017923s]
# Searching alignments...  [0.108135s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 2.
# Building reference index...  [0.300762s]
# Building query index...  [0.013559s]
# Building seed filter...  [0.017796s]
# Searching alignments...  [0.105595s]
# Processing query chunk 0, reference chunk 0, shape 1, index chunk 3.
# Building reference index...  [0.255979s]
# Building query index...  [0.016557s]
# Building seed filter...  [0.020447s]
# Searching alignments...  [0.109158s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 0.
# Building reference index...  [0.264203s]
# Building query index...  [0.010983s]
# Building seed filter...  [0.017622s]
# Searching alignments...  [0.126799s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 1.
# Building reference index...  [0.286582s]
# Building query index...  [0.012557s]
# Building seed filter...  [0.018012s]
# Searching alignments...  [0.116909s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 2.
# Building reference index...  [0.311564s]
# Building query index...  [0.014043s]
# Building seed filter...  [0.019507s]
# Searching alignments...  [0.11351s]
# Processing query chunk 0, reference chunk 0, shape 2, index chunk 3.
# Building reference index...  [0.258628s]
# Building query index...  [0.011368s]
# Building seed filter...  [0.017898s]
# Searching alignments...  [0.12453s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 0.
# Building reference index...  [0.251635s]
# Building query index...  [0.012492s]
# Building seed filter...  [0.01756s]
# Searching alignments...  [0.115321s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 1.
# Building reference index...  [0.287504s]
# Building query index...  [0.013856s]
# Building seed filter...  [0.017857s]
# Searching alignments...  [0.11415s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 2.
# Building reference index...  [0.349203s]
# Building query index...  [0.020581s]
# Building seed filter...  [0.017662s]
# Searching alignments...  [0.110495s]
# Processing query chunk 0, reference chunk 0, shape 3, index chunk 3.
# Building reference index...  [0.256126s]
# Building query index...  [0.01076s]
# Building seed filter...  [0.017945s]
# Searching alignments...  [0.117521s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 0.
# Building reference index...  [0.25382s]
# Building query index...  [0.011493s]
# Building seed filter...  [0.017627s]
# Searching alignments...  [0.114383s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 1.
# Building reference index...  [0.28906s]
# Building query index...  [0.012824s]
# Building seed filter...  [0.018372s]
# Searching alignments...  [0.114983s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 2.
# Building reference index...  [0.305334s]
# Building query index...  [0.014085s]
# Building seed filter...  [0.017621s]
# Searching alignments...  [0.114449s]
# Processing query chunk 0, reference chunk 0, shape 4, index chunk 3.
# Building reference index...  [0.251902s]
# Building query index...  [0.011444s]
# Building seed filter...  [0.017472s]
# Searching alignments...  [0.110997s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 0.
# Building reference index...  [0.252408s]
# Building query index...  [0.010793s]
# Building seed filter...  [0.017765s]
# Searching alignments...  [0.118779s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 1.
# Building reference index...  [0.286031s]
# Building query index...  [0.012334s]
# Building seed filter...  [0.018443s]
# Searching alignments...  [0.108539s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 2.
# Building reference index...  [0.301496s]
# Building query index...  [0.014066s]
# Building seed filter...  [0.017928s]
# Searching alignments...  [0.112063s]
# Processing query chunk 0, reference chunk 0, shape 5, index chunk 3.
# Building reference index...  [0.268075s]
# Building query index...  [0.010459s]
# Building seed filter...  [0.017978s]
# Searching alignments...  [0.115137s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 0.
# Building reference index...  [0.257663s]
# Building query index...  [0.012255s]
# Building seed filter...  [0.018276s]
# Searching alignments...  [0.110264s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 1.
# Building reference index...  [0.282424s]
# Building query index...  [0.012297s]
# Building seed filter...  [0.018849s]
# Searching alignments...  [0.1052s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 2.
# Building reference index...  [0.312552s]
# Building query index...  [0.013617s]
# Building seed filter...  [0.017348s]
# Searching alignments...  [0.103878s]
# Processing query chunk 0, reference chunk 0, shape 6, index chunk 3.
# Building reference index...  [0.247226s]
# Building query index...  [0.011398s]
# Building seed filter...  [0.018808s]
# Searching alignments...  [0.111732s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 0.
# Building reference index...  [0.263956s]
# Building query index...  [0.013052s]
# Building seed filter...  [0.018394s]
# Searching alignments...  [0.124925s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 1.
# Building reference index...  [0.308733s]
# Building query index...  [0.016094s]
# Building seed filter...  [0.0195s]
# Searching alignments...  [0.131902s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 2.
# Building reference index...  [0.30687s]
# Building query index...  [0.02036s]
# Building seed filter...  [0.019125s]
# Searching alignments...  [0.10964s]
# Processing query chunk 0, reference chunk 0, shape 7, index chunk 3.
# Building reference index...  [0.250446s]
# Building query index...  [0.013138s]
# Building seed filter...  [0.01857s]
# Searching alignments...  [0.120296s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 0.
# Building reference index...  [0.253527s]
# Building query index...  [0.011885s]
# Building seed filter...  [0.017674s]
# Searching alignments...  [0.117142s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 1.
# Building reference index...  [0.313819s]
# Building query index...  [0.013285s]
# Building seed filter...  [0.018328s]
# Searching alignments...  [0.130086s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 2.
# Building reference index...  [0.318064s]
# Building query index...  [0.014342s]
# Building seed filter...  [0.01832s]
# Searching alignments...  [0.125005s]
# Processing query chunk 0, reference chunk 0, shape 8, index chunk 3.
# Building reference index...  [0.26969s]
# Building query index...  [0.013839s]
# Building seed filter...  [0.019696s]
# Searching alignments...  [0.132499s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 0.
# Building reference index...  [0.260564s]
# Building query index...  [0.011101s]
# Building seed filter...  [0.017925s]
# Searching alignments...  [0.107139s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 1.
# Building reference index...  [0.30381s]
# Building query index...  [0.015631s]
# Building seed filter...  [0.01911s]
# Searching alignments...  [0.114515s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 2.
# Building reference index...  [0.328403s]
# Building query index...  [0.015102s]
# Building seed filter...  [0.019701s]
# Searching alignments...  [0.114906s]
# Processing query chunk 0, reference chunk 0, shape 9, index chunk 3.
# Building reference index...  [0.254156s]
# Building query index...  [0.011229s]
# Building seed filter...  [0.017683s]
# Searching alignments...  [0.112701s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 0.
# Building reference index...  [0.256006s]
# Building query index...  [0.010749s]
# Building seed filter...  [0.019035s]
# Searching alignments...  [0.121466s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 1.
# Building reference index...  [0.314359s]
# Building query index...  [0.012439s]
# Building seed filter...  [0.01696s]
# Searching alignments...  [0.114034s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 2.
# Building reference index...  [0.313462s]
# Building query index...  [0.014277s]
# Building seed filter...  [0.018043s]
# Searching alignments...  [0.116662s]
# Processing query chunk 0, reference chunk 0, shape 10, index chunk 3.
# Building reference index...  [0.264524s]
# Building query index...  [0.010578s]
# Building seed filter...  [0.018199s]
# Searching alignments...  [0.124868s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 0.
# Building reference index...  [0.254753s]
# Building query index...  [0.013204s]
# Building seed filter...  [0.018172s]
# Searching alignments...  [0.111185s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 1.
# Building reference index...  [0.297729s]
# Building query index...  [0.014738s]
# Building seed filter...  [0.019724s]
# Searching alignments...  [0.108033s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 2.
# Building reference index...  [0.313191s]
# Building query index...  [0.013855s]
# Building seed filter...  [0.018212s]
# Searching alignments...  [0.108113s]
# Processing query chunk 0, reference chunk 0, shape 11, index chunk 3.
# Building reference index...  [0.257515s]
# Building query index...  [0.0103s]
# Building seed filter...  [0.017849s]
# Searching alignments...  [0.119068s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 0.
# Building reference index...  [0.252366s]
# Building query index...  [0.011842s]
# Building seed filter...  [0.017916s]
# Searching alignments...  [0.112033s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 1.
# Building reference index...  [0.28791s]
# Building query index...  [0.01287s]
# Building seed filter...  [0.017798s]
# Searching alignments...  [0.111776s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 2.
# Building reference index...  [0.323016s]
# Building query index...  [0.013811s]
# Building seed filter...  [0.018758s]
# Searching alignments...  [0.113327s]
# Processing query chunk 0, reference chunk 0, shape 12, index chunk 3.
# Building reference index...  [0.294105s]
# Building query index...  [0.011112s]
# Building seed filter...  [0.017632s]
# Searching alignments...  [0.115373s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 0.
# Building reference index...  [0.282405s]
# Building query index...  [0.011498s]
# Building seed filter...  [0.017843s]
# Searching alignments...  [0.108767s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 1.
# Building reference index...  [0.295567s]
# Building query index...  [0.013079s]
# Building seed filter...  [0.020965s]
# Searching alignments...  [0.118868s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 2.
# Building reference index...  [0.307802s]
# Building query index...  [0.015181s]
# Building seed filter...  [0.017941s]
# Searching alignments...  [0.110154s]
# Processing query chunk 0, reference chunk 0, shape 13, index chunk 3.
# Building reference index...  [0.253875s]
# Building query index...  [0.010322s]
# Building seed filter...  [0.01783s]
# Searching alignments...  [0.114693s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 0.
# Building reference index...  [0.255716s]
# Building query index...  [0.010543s]
# Building seed filter...  [0.017727s]
# Searching alignments...  [0.121405s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 1.
# Building reference index...  [0.294146s]
# Building query index...  [0.012843s]
# Building seed filter...  [0.0178s]
# Searching alignments...  [0.110594s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 2.
# Building reference index...  [0.302545s]
# Building query index...  [0.013675s]
# Building seed filter...  [0.018809s]
# Searching alignments...  [0.109189s]
# Processing query chunk 0, reference chunk 0, shape 14, index chunk 3.
# Building reference index...  [0.250333s]
# Building query index...  [0.012282s]
# Building seed filter...  [0.017924s]
# Searching alignments...  [0.121444s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 0.
# Building reference index...  [0.250982s]
# Building query index...  [0.010986s]
# Building seed filter...  [0.017863s]
# Searching alignments...  [0.113728s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 1.
# Building reference index...  [0.287065s]
# Building query index...  [0.013022s]
# Building seed filter...  [0.018507s]
# Searching alignments...  [0.109249s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 2.
# Building reference index...  [0.310079s]
# Building query index...  [0.013412s]
# Building seed filter...  [0.018425s]
# Searching alignments...  [0.108911s]
# Processing query chunk 0, reference chunk 0, shape 15, index chunk 3.
# Building reference index...  [0.245709s]
# Building query index...  [0.011979s]
# Building seed filter...  [0.017903s]
# Searching alignments...  [0.113283s]
# Deallocating buffers...  [1.4e-05s]
# Computing alignments...  [5.30627s]
# Deallocating reference...  [1.1e-05s]
# Loading reference sequences...  [1.5e-05s]
# Deallocating buffers...  [3e-06s]
# Deallocating queries...  [6e-06s]
# Loading query sequences...  [9e-06s]
# Closing the input file...  [1.4e-05s]
# Closing the output file...  [0.000226s]
# Closing the database file...  [6e-06s]
# Total time = 34.3796s
# Reported 51679 pairwise alignments, 52204 HSPs.
# 3501 queries aligned.
